# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# Load files, read csv and store into Pandas DF
school_data = pd.read_csv("Resources/schools_complete.csv")
student_data = pd.read_csv("Resources/students_complete.csv")

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#DISTRICT SUMMARY TABLE
#Calculate the total number of schools
total_schools = len(school_data['school_name'].unique())
#Calculate the total number of students
total_num_of_stu = school_data['size'].sum()
#Calculate the total budget
total_budget = school_data['budget'].sum()
#Calculate the average math score
average_math_score = student_data['math_score'].mean()
#Calculate the average reading score
average_reading_score = student_data['reading_score'].mean()
#Calculate the percentage of students with a passing math score (70 or greater)
pass_math_df= school_data_complete.loc[school_data_complete['math_score']>=70, ['Student ID','math_score']]
tot_pass_math = pass_math_df.shape[0]
percentage_passing_math = tot_pass_math/total_num_of_stu
#Calculate the percentage of students with a passing reading score (70 or greater)
pass_reading_df = school_data_complete.loc[school_data_complete['reading_score']>=70, ['Student ID','reading_score']]
tot_pass_reading = pass_reading_df.shape[0]
percentage_passing_reading = tot_pass_reading/total_num_of_stu
#Calculate the percentage of students who passed math and reading (% Overall Passing)
merge_passing_df = pd.merge(pass_math_df,pass_reading_df, how="inner", on=["Student ID"])
tot_overall_pass = merge_passing_df.shape[0]
percentage_overall_pass = tot_overall_pass/total_num_of_stu
#Create a dataframe to hold the above results
district_summary = pd.DataFrame({"Total Schools": [total_schools], "Total Students": total_num_of_stu, 'Total Budget': total_budget, 'Average Math Score': average_math_score, 'Average Reading Score': average_reading_score, '% Passing Math': percentage_passing_math, '% Passing Reading': percentage_passing_reading, '% Overall Passing': percentage_overall_pass})
district_summary
#Optional: give the displayed data cleaner formatting
district_summary.style.format({"Total Students": "{:,}","Total Budget": "${:,.2f}", 
                       "Average Reading Score": "{:.0f}", 
                       "Average Math Score": "{:.0f}", 
                       "% Passing Math": "{:.2%}", 
                       "% Passing Reading": "{:.2%}", 
                       "% Overall Passing": "{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_f428767a_e4a3_11ea_9d8f_f40f240fb6fc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >% Passing Math</th>        <th class="col_heading level0 col6" >% Passing Reading</th>        <th class="col_heading level0 col7" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f428767a_e4a3_11ea_9d8f_f40f240fb6fclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f428767a_e4a3_11ea_9d8f_f40f240fb6fcrow0_col0" class="data row0 col0" >15</td>
# ...

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#SCHOOL SUMMARY TABLE
#School Name
school_gp = school_data_complete.groupby(['school_name'])
#School Type
sch_type = school_data.set_index(['school_name'])['type']
#Total Students
sch_students = school_data_complete['school_name'].value_counts()

#Total School Budget
tot_sch_budget = school_gp.mean()['budget']

#Per Student Budget
sch_stud_budget = (tot_sch_budget / sch_students)

#Average Math Score
sch_avg_math = school_gp.mean()['math_score']

#Average Reading Score
sch_avg_reading = school_gp.mean()['reading_score']

#Percentage Passing Math
math_pass_df = school_data_complete.loc[school_data_complete['math_score'] >= 70]
math_pass = math_pass_df['school_name'].value_counts()
math_pass_pct = math_pass / sch_students

#Percentage Passing Reading
read_pass_df = school_data_complete.loc[school_data_complete['reading_score'] >= 70]
read_pass = read_pass_df['school_name'].value_counts()
read_pass_pct = read_pass / sch_students

#Percentage Overall Passing (The percentage of students that passed math and reading
overall_pass_df= school_data_complete.loc[(school_data_complete['reading_score'] >= 70) & (school_data_complete['math_score'] >= 70)]
overall_pass = overall_pass_df['school_name'].value_counts()
overall_pass_pct = overall_pass / sch_students

#School Summary Dataframe 
school_summary = pd.DataFrame({'School Type': sch_type,
                                'No. of Students': sch_students,
                                'School Budget': tot_sch_budget,
                                'Budget per Student': sch_stud_budget,
                                'Average Math Score': sch_avg_math,
                                'Average Reading Score': sch_avg_reading,
                                '% Passing Math': math_pass_pct,
                                '% Passing Reading': read_pass_pct,
                                '% Passing Overall': overall_pass_pct
                              })
school_summary
# Out:
#                       School Type  No. of Students  School Budget  \
# Bailey High School       District             4976      3124928.0
# Cabrera High School       Charter             1858      1081356.0
# Figueroa High School     District             2949      1884411.0
# Ford High School         District             2739      1763916.0
# Griffin High School       Charter             1468       917500.0
# Hernandez High School    District             4635      3022020.0
# Holden High School        Charter              427       248087.0
# Huang High School        District             2917      1910635.0
# Johnson High School      District             4761      3094650.0
# Pena High School          Charter              962       585858.0
# Rodriguez High School    District             3999      2547363.0
# Shelton High School       Charter             1761      1056600.0
# Thomas High School        Charter             1635      1043130.0
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_five = school_summary.sort_values(['% Passing Overall'], ascending = False)
top_five.head(5)
# Out:
#                     School Type  No. of Students  School Budget  \
# Cabrera High School     Charter             1858      1081356.0
# Thomas High School      Charter             1635      1043130.0
# Griffin High School     Charter             1468       917500.0
# Wilson High School      Charter             2283      1319574.0
# Pena High School        Charter              962       585858.0
#
#                      Budget per Student  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780        0.941335           0.970398
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_five = school_summary.sort_values(['% Passing Overall'], ascending = True)
bottom_five.head(5)
# Out:
#                       School Type  No. of Students  School Budget  \
# Rodriguez High School    District             3999      2547363.0
# Figueroa High School     District             2949      1884411.0
# Huang High School        District             2917      1910635.0
# Hernandez High School    District             4635      3022020.0
# Johnson High School      District             4761      3094650.0
#
#                        Budget per Student  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686        0.663666
# Figueroa High School               81.158020        0.659885
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#Math Scores by Grade
#Create a pandas series for each grade. Hint: use a conditional statement.
nine_scr = school_data_complete.loc[school_data_complete['grade'] == '9th',:]
ten_scr = school_data_complete.loc[school_data_complete['grade'] == '10th',:]
eleven_scr = school_data_complete.loc[school_data_complete['grade'] == '11th',:]
twelve_scr = school_data_complete.loc[school_data_complete['grade'] == '12th',:]

#Group each series by school
nine_gb = nine_scr.groupby('school_name')
ten_gb = ten_scr.groupby('school_name')
eleven_gb = eleven_scr.groupby('school_name')
twelve_gb = twelve_scr.groupby('school_name')

#Create series of students for Average Math Scores
nine_avg_math = nine_gb['math_score'].mean()
ten_avg_math = ten_gb['math_score'].mean()
eleven_avg_math= eleven_gb['math_score'].mean()
twelve_avg_math = twelve_gb['math_score'].mean()

#Combine the series into a dataframe
math_score_summary = pd.DataFrame({
                '9th Grade Math Score': nine_avg_math,
                '10th Grade Math Score': ten_avg_math,
                '11th Grade Math Score': eleven_avg_math,
                '12th Grade Math Score': twelve_avg_math
        })
math_score_summary
# Out:
#                        9th Grade Math Score  10th Grade Math Score  \
# school_name
# Bailey High School                77.083676              76.996772
# Cabrera High School               83.094697              83.154506
# Figueroa High School              76.403037              76.539974
# Ford High School                  77.361345              77.672316
# Griffin High School               82.044010              84.229064
# Hernandez High School             77.438495              77.337408
# Holden High School                83.787402              83.429825
# Huang High School                 77.027251              75.908735
# Johnson High School               77.187857              76.691117
# Pena High School                  83.625455              83.372000
# Rodriguez High School             76.859966              76.612500
# Shelton High School               83.420755              82.917411
# Thomas High School                83.590022              83.087886
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#Create series of students for Average Reading Scores
nine_avg_read = nine_gb['reading_score'].mean()
ten_avg_read = ten_gb['reading_score'].mean()
eleven_avg_read= eleven_gb['reading_score'].mean()
twelve_avg_read = twelve_gb['reading_score'].mean()

#Combine the series into a dataframe
read_score_summary = pd.DataFrame({
                '9th Grade Reading Score': nine_avg_read,
                '10th Grade Reading Score': ten_avg_read,
                '11th Grade Reading Score': eleven_avg_read,
                '12th Grade Reading Score': twelve_avg_read
        })
read_score_summary
# Out:
#                        9th Grade Reading Score  10th Grade Reading Score  \
# school_name
# Bailey High School                   81.303155                 80.907183
# Cabrera High School                  83.676136                 84.253219
# Figueroa High School                 81.198598                 81.408912
# Ford High School                     80.632653                 81.262712
# Griffin High School                  83.369193                 83.706897
# Hernandez High School                80.866860                 80.660147
# Holden High School                   83.677165                 83.324561
# Huang High School                    81.290284                 81.512386
# Johnson High School                  81.260714                 80.773431
# Pena High School                     83.807273                 83.612000
# Rodriguez High School                80.993127                 80.629808
# Shelton High School                  84.122642                 83.441964
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
#Scores by School Spending

#Create 4 bins
budget_bins = [0, 584, 630, 645, 675]

#Label bins
budget_labels = [' < $584', '$ 585 - 629', '$ 630 - 644', '$ 645 - 675']

#Slice data 
pd.cut(school_summary['Budget per Student'], budget_bins, labels=budget_labels)
school_summary['Spending Category'] = pd.cut(school_summary['Budget per Student'], budget_bins, labels=budget_labels)
spending_gp = school_summary.groupby('Spending Category')
school_spending_summary = spending_gp[['Average Math Score','Average Reading Score','% Passing Math','% Passing Reading', '% Passing Overall']].mean()
school_spending_summary
# Out:
#                    Average Math Score  Average Reading Score  % Passing Math  \
# Spending Category
#  < $584                     83.455399              83.933814        0.934601
# $ 585 - 629                 81.899826              83.155286        0.871335
# $ 630 - 644                 78.518855              81.624473        0.734842
# $ 645 - 675                 76.997210              81.027843        0.661648
#
#                    % Passing Reading  % Passing Overall
# Spending Category
#  < $584                     0.966109           0.903695
# $ 585 - 629                 0.927182           0.814186
# $ 630 - 644                 0.843918           0.628577
# $ 645 - 675                 0.811340           0.535269

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
#Scores by School Size
#Create 4 bins
sz_bins = [0, 1000, 2000, 5000]

#Label bins
sz_labels = ['Small (<1000)', 'Medium (1000 - 2000)', 'Large (2000 - 5000)']

#Slice data 
pd.cut(school_summary['No. of Students'],sz_bins, labels = sz_labels)
school_summary['School Size'] = pd.cut(school_summary['No. of Students'], sz_bins, labels=sz_labels)
spending_gp = school_summary.groupby('School Size')
school_size_summary = spending_gp[['Average Math Score','Average Reading Score','% Passing Math','% Passing Reading','% Passing Overall']].mean()
school_size_summary
# Out:
#                       Average Math Score  Average Reading Score  \
# School Size
# Small (<1000)                  83.821598              83.929843
# Medium (1000 - 2000)           83.374684              83.864438
# Large (2000 - 5000)            77.746417              81.344493
#
#                       % Passing Math  % Passing Reading  % Passing Overall
# School Size
# Small (<1000)               0.935502           0.960994           0.898839
# Medium (1000 - 2000)        0.935997           0.967907           0.906215
# Large (2000 - 5000)         0.699634           0.827666           0.582860

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
#scores_df = pd.DataFrame({'School Type': sch_type,
#                          'Average Math Score': sch_avg_math,
#                          'Ave Reading Score': sch_avg_reading,
#                          '% Passing Math': s_m_pass_pct,
#                          '% Passing Reading': s_r_pass_pct,
#                          '% Passing Overall': s_o_pass_pct
#                         })
scores_df = school_summary[{'School Type',
                            'Average Math Score', 
                            'Average Reading Score', 
                            '% Passing Math', 
                            '% Passing Reading', 
                            '% Passing Overall'}]


#scores_df.head()




types_gb = scores_df.groupby(['School Type'])

tot_math_avg = types_gb['Average Math Score'].mean()
tot_read_avg = types_gb['Average Reading Score'].mean()
tot_math_pass = types_gb['% Passing Math'].mean()
tot_read_pass = types_gb['% Passing Reading'].mean()
tot_overall_pass = types_gb['% Passing Overall'].mean()


types_df = pd.DataFrame({ 'Average Math Score': tot_math_avg,
                          'Average Reading Score': tot_read_avg,
                          '% Passing Math': tot_math_pass,
                          '% Passing Reading': tot_read_pass,
                          '% Passing Overall': tot_overall_pass
                         })
types_df.head()
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421        0.936208
# District              76.956733              80.966636        0.665485
#
#              % Passing Reading  % Passing Overall
# School Type
# Charter               0.965865           0.904322
# District              0.807991           0.536722
